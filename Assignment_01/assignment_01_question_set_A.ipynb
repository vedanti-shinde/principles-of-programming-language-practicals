# %% [markdown]
# <h3>ASSIGNMENT NO.1: BASIC PYTHON<h3>

# %% [markdown]
# <h3>Question Set A<h3>

# %%
#1) Write a Python Program to Calculate the Average of Numbers in a Given List.
numbers = [10, 20, 30, 40, 50]

average = sum(numbers) / len(numbers)
print("Average:", average)
# Out:
# Average: 30.0

# %%
#2) Write a program which accepts 6 integer values and prints "DUPLICATES" if any of the
#values entered are duplicates otherwise it prints "ALL UNIQUE".
values = []

for i in range(6):
    num = int(input(f"Enter integer {i+1}: "))
    values.append(num)

if len(values) != len(set(values)):
    print("DUPLICATES")
else:
    print("ALL UNIQUE")
# Out:
# Enter integer 1:  7
# Enter integer 2:  6
# Enter integer 3:  8
# Enter integer 4:  8
# Enter integer 5:  9
# Enter integer 6:  9
# DUPLICATES

# %%
#3) Write a program which accepts an integer value as input and print "Ok" if value is between
#1 to 50 (both inclusive) otherwise it prints "Out of range".
num = int(input("Enter an integer value: "))

if num >= 1 and num <= 50:
    print("Ok")
else:
    print("Out of range")
# Out:
# Enter an integer value:  87
# Out of range

# %%
#4) Write a program which finds sum of digits of a number.
#Example: n=130 then output is 4 (1+3+0).
n = int(input("Enter a number: "))
sum = 0

while n > 0:
    digit = n % 10
    sum = sum + digit
    n = n // 10

print("Sum of digits is:", sum)
# Out:
# Enter a number:  6
# Sum of digits is: 6

# %%
#5) Write a program which prints Fibonacci series of a number.
# Program to print Fibonacci series
n = int(input("Enter how many terms: "))
a = 0
b = 1

print("Fibonacci series:")

for i in range(n):
    print(a, end=" ")
    c = a + b
    a = b
    b = c
# Out:
# Enter how many terms:  9
# Fibonacci series:
# 0 1 1 2 3 5 8 13 21
