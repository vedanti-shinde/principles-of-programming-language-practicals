# %% [markdown]
# <h3>ASSIGNMENT NO.2: PYTHON STRINGS <h3>

# %% [markdown]
# <h3>Question Set B<h3>

# %%
#1) Write a program to find the first non-repeating character in a string
s = input("Enter a string: ")

found = False

for ch in s:
    if s.count(ch) == 1:
        print("First non-repeating character is:", ch)
        found = True
        break

if not found:
    print("No non-repeating character found")
# Out:
# Enter a string:  hello world
# First non-repeating character is: h

# %%
#2) Write a program to check if two strings are anagrams (contain same characters in different order).
#Example: "listen" and "silent" are anagrams.
s1 = input("Enter first string: ")
s2 = input("Enter second string: ")

if sorted(s1) == sorted(s2):
    print("Strings are anagrams")
else:
    print("Strings are not anagrams")
# Out:
# Enter first string:  cat
# Enter second string:  ate
# Strings are not anagrams

# %%
#3) Write a program to convert a string to title case without using the title() method. Example: "python programming" should become "Python Programming"
s = input("Enter a string: ")

words = s.split()
result = ""

for word in words:
    result = result + word[0].upper() + word[1:] + " "

print("Title case string is:", result.strip())
# Out:
# Enter a string:  python programming
# Title case string is: Python Programming

# %%
#4) Write a program to replace all occurrences of a substring with another substring in a given string.
s = input("Enter the main string: ")
old = input("Enter the substring to be replaced: ")
new = input("Enter the new substring: ")

result = s.replace(old, new)

print("Modified string is:", result)
# Out:
# Enter the main string:  hello world hey
# Enter the substring to be replaced:  hey
# Enter the new substring:  hi
# Modified string is: hello world hi
