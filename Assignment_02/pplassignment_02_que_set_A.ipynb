# %% [markdown]
# <h3>ASSIGNMENT NO.2: PYTHON STRINGS <h3>

# %% [markdown]
# <h3>Question Set A<h3>

# %%
#1) Write a program to count the number of vowels in a given string.
s = input("Enter a string: ")
count = 0

for ch in s:
    if ch in "aeiouAEIOU":
        count = count + 1

print("Number of vowels:", count)
# Out:
# Enter a string:  helloooo
# Number of vowels: 5

# %%
#2) Write a program to check if a string is a palindrome (reads the same forwards and backwards).
s = input("Enter a string: ")

rev = s[::-1]

if s == rev:
    print("String is a palindrome")
else:
    print("String is not a palindrome")
# Out:
# Enter a string:  swim
# String is not a palindrome

# %%
#3) Write a program to reverse a string without using built-in reverse functions
s = input("Enter a string: ")
rev = ""

for ch in s:
    rev = ch + rev

print("Reversed string is:", rev)
# Out:
# Enter a string:  cat
# Reversed string is: tac

# %%
#4) Write a program to count the frequency of each character in a string.
#Example: For "hello", output should be h:1, e:1, l:2, o:1
s = input("Enter a string: ")

for ch in s:
    print(ch, ":", s.count(ch))
# Out:
# Enter a string:  kittyyy
# k : 1
# i : 1
# t : 2
# t : 2
# y : 3
# y : 3
# y : 3

# %%
#5) Write a program to remove all whitespace from a string.
s = input("Enter a string: ")
result = ""

for ch in s:
    if ch != " ":
        result = result + ch

print("String without whitespace:", result)
# Out:
# Enter a string:  hello world hi world
# String without whitespace: helloworldhiworld
